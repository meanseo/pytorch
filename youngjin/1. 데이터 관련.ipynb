# %% [markdown]
# ## 데이터 관련
# 데이터는 로컬 데이터와 파이토치에서 제공하는 데이터로 구성되어 있습니다.
# 파이토치 데이터는 torchvision 라이브러리를 통해 자동으로 생성이 됩니다.
# 혹시나 아주 작은 확률로 생성이 안 되실 경우에는 아래 링크를 통해 다운로드 받은 파일을 data 폴더에 넣어 주시면 됩니다.
# https://drive.google.com/drive/folders/1lqrYo-V3a0cj1do-mMBoP5sWeGVn4hae?usp=sharing
#
# 1. CIFAR10
# 2. CIFAR100
# 3. Fashion MNIST
# 4. MNIST
# 5. STL10
