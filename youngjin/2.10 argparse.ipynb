# %% [markdown]
# # 2. 파이썬
# ## 2.9 터미널에서 파이썬 실행하기

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/My Drive/pytorch_dlbro
# Out:
# /content/gdrive/My Drive/pytorch_dlbro

# %%
# !python arg_example.py --cv 3 --img_size 64
# Out:
# Namespace(batch_size=30, cutmix='n', cv=3, data=2, img_size=64, l2=0, lr=0.0005, ls=0.2, num_epochs=101, type='train')
# Completed

# %% [markdown]
# ## Shell file 만들기

# %%
"""
python arg_example.py --data 1
python arg_example.py --data 3 --ls 0.4
python arg_example.py --l2 1e-4 --cutmix 'y'
"""
# !sh execute.sh
# Out:
# Namespace(batch_size=30, cutmix='n', cv=3, data=1, img_size=216, l2=0, lr=0.0005, ls=0.2, num_epochs=101, type='train')
# Completed
# Namespace(batch_size=30, cutmix='n', cv=3, data=3, img_size=216, l2=0, lr=0.0005, ls=0.4, num_epochs=101, type='train')
# Completed
# Namespace(batch_size=30, cutmix='y', cv=3, data=2, img_size=216, l2=0.0001, lr=0.0005, ls=0.2, num_epochs=101, type='train')
# Completed
