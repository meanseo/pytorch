# %% [markdown]
# 본 예제는 학습시간 단축과 데이터 용량을 줄이기 위해 축소 된 데이터를 사용하였습니다. 따라서 원 데이터로 학습 할 때보다 정확도가 떨어질 수 있지만 구동 원리를 이해 하시는데에는 문제가 없습니다.
#
# 원 데이터가 필요하신 분들은 아래 링크를 통해 논문 저자가 공유하는 데이터를 확인하실 수 있습니다. (Cylinder2D_flower.mat 약 916Mb)
# https://drive.google.com/drive/folders/1mrJzBi1_IhbVebjeJ0qIo5dEx3f7xrQi

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/My Drive/pytorch_dlbro/HFM

# %%
# !python train.py --modelpath './hfm_0.pth'

# %%
# !python evaluation.py
