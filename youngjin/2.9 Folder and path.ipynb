# %% [markdown]
# # 2. 파이썬
# ## 2.9 폴더 및 파일 관리

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\MyProject\yolov5\app\2.9 Folder and path.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/MyProject/yolov5/app/2.9%20Folder%20and%20path.ipynb#ch0000001?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/MyProject/yolov5/app/2.9%20Folder%20and%20path.ipynb#ch0000001?line=1'>2</a> drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
cd/content/gdrive/My Drive/pytorch_dlbro
# Out:
# /content/gdrive/My Drive/pytorch_dlbro

# %%
import os

def newfolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print('Error')

# %%
parent_folder = './new'
newfolder(parent_folder)

# %% [markdown]
# ## 경로 불러오기

# %%
import glob

path = glob.glob('./data/*')
print(path)
# Out:
# ['./data/cifar-10-batches-py', './data/cifar-100-python', './data/kospi.csv', './data/cifar-10-python.tar.gz', './data/cifar-100-python.tar.gz', './data/stl10_binary.tar.gz', './data/stl10_binary', './data/MNIST', './data/FashionMNIST', './data/imgA.jpg', './data/imgB.jpg']
