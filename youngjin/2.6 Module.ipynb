# %% [markdown]
# # 2. 파이썬
# ## 2.6 모듈

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd/content/gdrive/My Drive/deeplearningbro/python

# %%
import numpy as np
from module_example import linear_regression, gaussian_mixture,random_forest

# import preprocess
# 등 ....

# models.py
# datasets.py
#....

# %%
data = np.random.randint(0,105, size=(10,5))

# %%
linear_regression(data)
# Out:
# Linear Regression

# %%
gaussian_mixture(data)
# Out:
# Gaussian Mixture

# %%
random_forest(data)
# Out:
# Random Forest
