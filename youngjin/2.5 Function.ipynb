# %% [markdown]
# # 2. 파이썬
# ## 2.5 함수

# %%
import numpy as np

# %% [markdown]
# ### 2.5.1 함수 정의

# %%
def sincos(x):
     return np.sin(x)+np.cos(x)

# %%
sincos(1)
# Out:
# 1.3817732906760363

# %%
sincos([1,2])
# Out:
# array([1.38177329, 0.49315059])
